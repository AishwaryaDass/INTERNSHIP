# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
per=pd.read_csv('/content/SampleSuperstore.csv')
per
# Out:
#            Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0       Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1       Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2       Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3     Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4     Standard Class   Consumer  United States  ...        2     0.20    2.5164
# ...              ...        ...            ...  ...      ...      ...       ...
# 9989    Second Class   Consumer  United States  ...        3     0.20    4.1028
# 9990  Standard Class   Consumer  United States  ...        2     0.00   15.6332
# 9991  Standard Class   Consumer  United States  ...        2     0.20   19.3932
# 9992  Standard Class   Consumer  United States  ...        4     0.00   13.3200
# 9993    Second Class   Consumer  United States  ...        2     0.00   72.9480
#
# ...

# %%
per.tail()
# Out:
#            Ship Mode   Segment        Country  ... Quantity Discount   Profit
# 9989    Second Class  Consumer  United States  ...        3      0.2   4.1028
# 9990  Standard Class  Consumer  United States  ...        2      0.0  15.6332
# 9991  Standard Class  Consumer  United States  ...        2      0.2  19.3932
# 9992  Standard Class  Consumer  United States  ...        4      0.0  13.3200
# 9993    Second Class  Consumer  United States  ...        2      0.0  72.9480
#
# [5 rows x 13 columns]

# %%
per.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
per.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
per.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#observing relationship between different parameters

sns.barplot(x='Region',y='Profit',data=per)

# %%
plt.figure(figsize=(10,15))
ax=sns.barplot(x='Profit',y='State',data=per)

# %%
sns.barplot(x='Category',y='Profit',data=per)

# %%
sns.barplot(x='Profit',y='Sub-Category',data=per)
plt.show()

# %%
sns.jointplot(x='Category',y='Region',data=per)
plt.show()

# %%
sns.jointplot(x='Region',y='Sub-Category',data=per)
plt.figure(figsize=(10,6))
plt.show()

# %%
sns.jointplot(x='Category',y='State',data=per)

# %%
sns.jointplot(x='Sub-Category',y='State',data=per)

# %%
#the analysis for city vs profit and state with category and subcategory is not very clear as the data is per large.
#hence to establish a relationship between them we use the pair plot for easy analysis

sns.pairplot(per)
plt.show()

# %%
#trying to bring relationship between profit and discount

sns.barplot(x='Discount',y='Profit',data=per)
plt.show()

# %%
#trying to see with the profit varies wrt the mode of shipment
sns.barplot(x='Ship Mode',y='Profit',data=per)
plt.show()
